# %% [markdown]
# ### DATA INGESTION

# %%
### Document datastructure

from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main conntent which i am goig to use for cretin rag applciation",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Shivam Tripathi",
        "date_created":"2026-05-05"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Shivam Tripathi', 'date_created': '2026-05-05'}, page_content='this is the main conntent which i am goig to use for cretin rag applciation')

# %%
## create simple txt file 
import os 

os.makedirs("../data/textfiles",exist_ok=True)

# %%
sample_texts={
    "../data/textfiles/ml_intor.txt":"""    
Introduction to ML
ML is a high-level, interpreted programming language known for its clear syntax and readability. Created by Guido van Rossum and first released in 1991, it has become one of the most popular languages in the world, powering everything from simple automation scripts to complex machine learning algorithms.

Its design philosophy emphasizes code readability, allowing developers to express concepts in fewer lines of code than might be possible in languages such as C++ or Java.

Key Features of Python
1. Simple and Easy to Learn

2. Interpreted Language

3. Dynamically Typed

Popular Use Cases

Field	Description
Web Development	Building the backend logic of websites and APIs.
Data Analysis	Processing large datasets and creating visual insights.
Machine Learning	Training models for image recognition or natural language processing.

"""
}
for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)
print("smaple file created")
# Out:
# smaple file created

# %%
### text loader 

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/textfiles/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/textfiles/python_intro.txt'}, page_content='    \nIntroduction to Python\nPython is a high-level, interpreted programming language known for its clear syntax and readability. Created by Guido van Rossum and first released in 1991, it has become one of the most popular languages in the world, powering everything from simple automation scripts to complex machine learning algorithms.\n\nIts design philosophy emphasizes code readability, allowing developers to express concepts in fewer lines of code than might be possible in languages such as C++ or Java.\n\nKey Features of Python\n1. Simple and Easy to Learn\n\n2. Interpreted Language\n\n3. Dynamically Typed\n\nPopular Use Cases\n\nField\tDescription\nWeb Development\tBuilding the backend logic of websites and APIs.\nData Analysis\tProcessing large datasets and creating visual insights.\nMachine Learning\tTraining models for image recognition or natural language processing.\n\n')]

# %%
### Directory Loader 
from langchain_community.document_loaders import DirectoryLoader

## load all the files from directory 

dir_loader=DirectoryLoader(
    "../data/textfiles",
    glob="**/*.txt", ## pattern to match files
    loader_cls=TextLoader ,## loader class to use 
    loader_kwargs={'encoding':'utf-8'},
    show_progress=False
)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/textfiles/python_intro.txt'}, page_content='    \nIntroduction to Python\nPython is a high-level, interpreted programming language known for its clear syntax and readability. Created by Guido van Rossum and first released in 1991, it has become one of the most popular languages in the world, powering everything from simple automation scripts to complex machine learning algorithms.\n\nIts design philosophy emphasizes code readability, allowing developers to express concepts in fewer lines of code than might be possible in languages such as C++ or Java.\n\nKey Features of Python\n1. Simple and Easy to Learn\n\n2. Interpreted Language\n\n3. Dynamically Typed\n\nPopular Use Cases\n\nField\tDescription\nWeb Development\tBuilding the backend logic of websites and APIs.\nData Analysis\tProcessing large datasets and creating visual insights.\nMachine Learning\tTraining models for image recognition or natural language processing.\n\n'),
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader

dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## pattern to match files
    loader_cls=PyMuPDFLoader ,## loader class to use 

    show_progress=False
)

pdf_document=dir_loader.load()
pdf_document
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-03T13:06:51+00:00', 'source': '../data/pdf/shivam_tripathi_v2.pdf', 'file_path': '../data/pdf/shivam_tripathi_v2.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-03T13:06:51+00:00', 'trapped': '', 'modDate': 'D:20260503130651Z', 'creationDate': 'D:20260503130651Z', 'page': 0}, page_content='SHIVAM TRIPATHI\n+91 8224966690 | shivam1705of@gmail.com | linkedin.com/in/iamtripathi | github.com/shivam261 | Portfolio\nWORK EXPERIENCE\nLTM (LTIMindtree)\nAug 2025 – Present\nFull Stack Developer (Consultant)\nPune, India\n• Improved React.js application performance by 15–20% through optimized components and efficient state management.\n• Streamlined rendering of large datasets using memoization and virtualization techniques.\n• Replaced a third-party solution with a custom-built system, achieving 65% cost savings
# ...
